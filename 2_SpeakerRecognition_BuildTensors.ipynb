# %% [markdown]
# # ITI110 Project - Speaker Recognition
#
# Team 9
#
# ## Part 2 - Building Tensors

# %%
import sys
import numpy as np
import pandas as pd
import librosa
import pickle
import os
from shutil import copyfile
import matplotlib.pyplot as plt
import imageio
# %matplotlib inline

import cv2
import time

import tensorflow as tf
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model

from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform

from keras.engine.topology import Layer
from keras.regularizers import l2
from keras import backend as K
from keras import initializers

import numpy.random as rng
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Folder paths

# %%
base_folder = "/Users/MacBookPro/AIandMLNYP/AIProject/SpeakerRecognition/TIMIT/"
data_folder = base_folder + "/data"
train_audio_folder = base_folder + "/Audio/TRAIN/"
test_audio_folder = base_folder + "/Audio/TEST/"
save_path = '/Users/MacBookPro/AIandMLNYP/AIProject/SpeakerRecognition/data/'
output_folder = base_folder + "/npydata/"

# %% [markdown]
# ### Converting to MFCC

# %%
# Each of our sample (16khz) lasts exactly from 3 - 5  seconds. We will truncate at 3 secs with 16000 * 3 samples.
#
mfcc_hop_length = 256
mfcc_max_frames = int(16000 * 3 / mfcc_hop_length) + 1

print ("MFCC Frames (for 3 sec audio):     %d" % (mfcc_max_frames))

num_classes = 10
max_samples = 16000 * 3  # 5 seconds
max_mfcc_features = 40

# Scale the values to be between 
def scale(arr):
    #arr = arr - arr.mean()
    safe_max = np.abs(arr).max()
    if safe_max == 0:
        safe_max = 1
    arr = arr / safe_max
    return arr


# Load a file and convert its audio signal into a series of MFCC
# This will return a 2D numpy array.
#
def convert_mfcc(file_name):
    signal, sample_rate = librosa.load(file_name) 
    signal = librosa.util.normalize(signal)
    signal_trimmed, index = librosa.effects.trim(signal, top_db=60)
    signal_trimmed = librosa.util.fix_length(signal_trimmed, max_samples)
    
    feature = (librosa.feature.mfcc(y=signal_trimmed, sr=sample_rate, n_mfcc=max_mfcc_features).T)

    if (feature.shape[0] > mfcc_max_frames):
        feature = feature[0:mfcc_max_frames, :]
    if (feature.shape[0] < mfcc_max_frames):
        feature = np.pad(feature, pad_width=((0, mfcc_max_frames - feature.shape[0]), (0,0)), mode='constant')
    
    # This removes the average component from the MFCC as it may not be meaningful.
    #
    feature[:,0] = 0
        
    feature = scale(feature)

    return feature
# Out:
# MFCC Frames (for 3 sec audio):     188

# %%
def convertAudio(path,n = 0):
    '''
    path => Path of train directory or test directory
    '''
    X = []
    y = []
    speaker_dict = {}
    mfcc_dict = {}
    speaker_dict = {}
    curr_y = n
    # convert and load the mfcc features for all audio files for each speaker
    for speaker in os.listdir(path):
        print("loading speaker: " + speaker)
        speaker_dict[speaker] = [curr_y, None]
        
        mfcc_list = []
        speaker_path = os.path.join(path,speaker)
        # read all the images in the current category
        for filename in os.listdir(speaker_path):
            file_path = os.path.join(speaker_path, filename)
            # convert the audio file to spectral
            mfcc = convert_mfcc(file_path)
            mfcc_list.append(mfcc)
            y.append(curr_y)
            curr_y += 1
        try:
            X.append(np.stack(mfcc_list))
            # edge case - last one
        except ValueError as e:
            print(e)
            print("error - category_images:", category_images)

        speaker_dict[speaker][1] = curr_y - 1

    y = np.vstack(y)
    X = np.stack(X)

    return  X, y,speaker_dict

# %% [markdown]
# ### Loading the training audio files into tensors

# %%
X, y,c=convertAudio(train_audio_folder)
print(X.shape)
print(c)
# Out:
# loading speaker: MDNS0
# loading speaker: FCRZ0
# loading speaker: MMDM0
# loading speaker: MKXL0
# loading speaker: MESJ0
# loading speaker: MRAV0
# loading speaker: FECD0
# loading speaker: FJKL0
# loading speaker: MCSS0
# loading speaker: MWRE0
# loading speaker: FDNC0
# loading speaker: MPRD0
# loading speaker: MCDR0
# loading speaker: MDAC0
# loading speaker: FSJG0
# loading speaker: MRLJ1
# loading speaker: MKDT0
# loading speaker: MLEL0
# loading speaker: MAKR0
# loading speaker: MAFM0
# loading speaker: FEEH0
# loading speaker: MGAK0
# loading speaker: MPSW0
# loading speaker: MMDG0
# loading speaker: MVRW0
# loading speaker: MWCH0
# loading speaker: MFWK0
# loading speaker: MILB0
# loading speaker: FNTB0
# loading speaker: FNKL0
# loading speaker: FKLH0
# loading speaker: MTJU0
# loading speaker: MHBS0
# loading speaker: MRLJ0
# loading speaker: FPMY0
# loading speaker: MJHI0
# loading speaker: MRMS0
# loading speaker: MJWG0
# loading speaker: MEFG0
# loading speaker: FBLV0
# loading speaker: MRBC0
# loading speaker: FMMH0
# loading speaker: FPJF0
# loading speaker: MRGS0
# loading speaker: MKAG0
# loading speaker: FDAS1
# loading speaker: MMDM1
# loading speaker: FSBK0
# loading speaker: MHRM0
# loading speaker: MKAM0
# loading speaker: MKLR0
# loading speaker: FMEM0
# loading speaker: FKFB0
# loading speaker: MWEM0
# loading speaker: MWAD0
# loading speaker: MAPV0
# loading speaker: FJXM0
# loading speaker: MBSB0
# loading speaker: MJDE0
# loading speaker: MSEM1
# loading speaker: MPGR1
# loading speaker: MRTC0
# loading speaker: MRKM0
# loading speaker: FTBR0
# loading speaker: MTAT0
# loading speaker: MGES0
# loading speaker: MSMS0
# loading speaker: MRJT0
# loading speaker: MJMA0
# loading speaker: MRAM0
# loading speaker: MTJM0
# loading speaker: MGJC0
# loading speaker: MRLR0
# loading speaker: MRRE0
# loading speaker: FGDP0
# loading speaker: MTJG0
# loading speaker: MRPC1
# loading speaker: MEJS0
# loading speaker: MJFR0
# loading speaker: MMCC0
# loading speaker: MDMT0
# loading speaker: MAJP0
# loading speaker: MDLM0
# loading speaker: FJHK0
# loading speaker: MCDC0
# loading speaker: FCJS0
# loading speaker: MGSH0
# loading speaker: FLKM0
# loading speaker: MCHL0
# loading speaker: MMGC0
# loading speaker: FLOD0
# loading speaker: MJXL0
# loading speaker: MDSJ0
# loading speaker: MMBS0
# loading speaker: MTPP0
# loading speaker: MTAT1
# loading speaker: MRMH0
# loading speaker: FVFB0
# loading speaker: MPGR0
# loading speaker: FCAJ0
# loading speaker: FLMK0
# loading speaker: FPAD0
# loading speaker: FMJF0
# loading speaker: FLMA0
# loading speaker: MTQC0
# loading speaker: MKJO0
# loading speaker: MREM0
# loading speaker: MRMB0
# loading speaker: FSLS0
# loading speaker: MBWP0
# loading speaker: FLAG0
# loading speaker: MBCG0
# loading speaker: MRTJ0
# loading speaker: MTLB0
# loading speaker: MHMR0
# loading speaker: FSKL0
# loading speaker: MFRM0
# loading speaker: MFMC0
# loading speaker: MDLC1
# loading speaker: MJRH0
# loading speaker: FCEG0
# loading speaker: MMAA0
# loading speaker: MTWH1
# loading speaker: FMBG0
# loading speaker: MRML0
# loading speaker: MSJK0
# loading speaker: MMAB1
# loading speaker: FKKH0
# loading speaker: MLSH0
# loading speaker: MTAS0
# loading speaker: FALK0
# loading speaker: MSVS0
# loading speaker: MSDB0
# loading speaker: MBTH0
# loading speaker: MGSL0
# loading speaker: MCEW0
# loading speaker: MJPG0
# loading speaker: MRXB0
# loading speaker: MMGG0
# loading speaker: MCLK0
# loading speaker: MJPM0
# loading speaker: MGAW0
# loading speaker: MSDH0
# loading speaker: MWDK0
# loading speaker: FLTM0
# loading speaker: MKDB0
# loading speaker: FJSK0
# loading speaker: MCDD0
# loading speaker: MDWM0
# loading speaker: FSAH0
# loading speaker: FLAC0
# loading speaker: FMJB0
# loading speaker: MMWS0
# loading speaker: MMEB0
# loading speaker: FBJL0
# loading speaker: MLJC0
# loading speaker: MJSR0
# loading speaker: MJAC0
# loading speaker: MTKP0
# loading speaker: MRAI0
# loading speaker: MJRK0
# loading speaker: FPAC0
# loading speaker: MDWD0
# loading speaker: MWAR0
# loading speaker: MJRH1
# loading speaker: FSCN0
# loading speaker: MDLC0
# loading speaker: MMWS1
# loading speaker: MBJV0
# loading speaker: MTRR0
# loading speaker: MJXA0
# loading speaker: FRLL0
# loading speaker: MWRP0
# loading speaker: MKLN0
# loading speaker: MJRA0
# loading speaker: MMEA0
# loading speaker: FTAJ0
# loading speaker: FCAG0
# loading speaker: FKAA0
# loading speaker: FJWB1
# loading speaker: FSMM0
# loading speaker: FSAK0
# loading speaker: MJPM1
# loading speaker: MJAI0
# loading speaker: MBEF0
# loading speaker: MRDS0
# loading speaker: FGMB0
# loading speaker: MPEB0
# loading speaker: MCAE0
# loading speaker: MHMG0
# loading speaker: MGAF0
# loading speaker: MJLG1
# loading speaker: FREH0
# loading speaker: MRJH0
# loading speaker: MDEM0
# loading speaker: MJJB0
# loading speaker: MFXV0
# loading speaker: MTMN0
# loading speaker: MARW0
# loading speaker: FVKB0
# loading speaker: FLHD0
# loading speaker: FETB0
# loading speaker: FTLG0
# loading speaker: MSFV0
# loading speaker: MCXM0
# loading speaker: MMWB0
# loading speaker: MRLD0
# loading speaker: FSDC0
# loading speaker: MDLR1
# loading speaker: MJDA0
# loading speaker: MESG0
# loading speaker: FBCH0
# loading speaker: FSSB0
# loading speaker: FAPB0
# loading speaker: FMPG0
# loading speaker: FLJA0
# loading speaker: FHXS0
# loading speaker: FJSP0
# loading speaker: MABC0
# loading speaker: MJBG0
# loading speaker: FGCS0
# loading speaker: MSDS0
# loading speaker: MCEF0
# loading speaker: FCJF0
# loading speaker: MTAB0
# loading speaker: MTRC0
# loading speaker: FBMH0
# loading speaker: MVJH0
# loading speaker: MDMA0
# loading speaker: FSDJ0
# loading speaker: MJRP0
# loading speaker: MCTH0
# loading speaker: FHLM0
# loading speaker: FDAW0
# loading speaker: FMKC0
# loading speaker: FGRW0
# loading speaker: MRJB1
# loading speaker: MTPF0
# loading speaker: FEXM0
# loading speaker: MEWM0
# loading speaker: MEJL0
# loading speaker: FDFB0
# loading speaker: MKAJ0
# loading speaker: MJKR0
# loading speaker: MRCW0
# loading speaker: MCAL0
# loading speaker: FSKP0
# loading speaker: MDLR0
# loading speaker: MWAC0
# loading speaker: MDED0
# loading speaker: MTML0
# loading speaker: MRFL0
# loading speaker: MGRL0
# loading speaker: FALR0
# loading speaker: MTJS0
# loading speaker: MVLO0
# loading speaker: MDBP0
# loading speaker: MSAH1
# loading speaker: MMRP0
# loading speaker: MMJB1
# loading speaker: MTPG0
# loading speaker: MMDB0
# loading speaker: MDTB0
# loading speaker: FSJK1
# loading speaker: MRWA0
# loading speaker: MDPK0
# loading speaker: MMLM0
# loading speaker: MJDC0
# loading speaker: MMAR0
# loading speaker: MDRD0
# loading speaker: MTDP0
# loading speaker: MPRK0
# loading speaker: MJJJ0
# loading speaker: MCRE0
# loading speaker: FCYL0
# loading speaker: MNTW0
# loading speaker: FBMJ0
# loading speaker: MGAG0
# loading speaker: FJRB0
# loading speaker: MMXS0
# loading speaker: MDHS0
# loading speaker: MPRB0
# loading speaker: FMAH1
# loading speaker: MPFU0
# loading speaker: MLNS0
# loading speaker: FPAZ0
# loading speaker: MDPB0
# loading speaker: MSTF0
# loading speaker: FAJW0
# loading speaker: FDMY0
# loading speaker: MRHL0
# loading speaker: MADD0
# loading speaker: MMVP0
# loading speaker: MDEF0
# loading speaker: FDXW0
# loading speaker: MKLW0
# loading speaker: MKAH0
# loading speaker: FAEM0
# loading speaker: MMDS0
# loading speaker: FTMG0
# loading speaker: FSRH0
# loading speaker: MJMD0
# loading speaker: MAEO0
# loading speaker: MKES0
# loading speaker: MBOM0
# loading speaker: MPAR0
# loading speaker: MBBR0
# loading speaker: MRCG0
# loading speaker: MDLB0
# loading speaker: FSGF0
# loading speaker: FTBW0
# loading speaker: MBMA1
# loading speaker: MWSB0
# loading speaker: MDBB1
# loading speaker: MWSH0
# loading speaker: MSES0
# loading speaker: MREH1
# loading speaker: FSJS0
# loading speaker: FJLG0
# loading speaker: MDLH0
# loading speaker: MSRR0
# loading speaker: MTER0
# loading speaker: MJEB1
# loading speaker: FSPM0
# loading speaker: MRAB0
# loading speaker: MTXS0
# loading speaker: FLEH0
# loading speaker: MZMB0
# loading speaker: MLJH0
# loading speaker: FJXP0
# loading speaker: MBMA0
# loading speaker: FRJB0
# loading speaker: FJDM2
# loading speaker: MRWS0
# loading speaker: MHJB0
# loading speaker: MTMT0
# loading speaker: FPAB1
# loading speaker: MSAS0
# loading speaker: MTDB0
# loading speaker: MRGM0
# loading speaker: FSKC0
# loading speaker: MHIT0
# loading speaker: FDKN0
# loading speaker: MEGJ0
# loading speaker: MRAB1
# loading speaker: FCKE0
# loading speaker: MMPM0
# loading speaker: FJRP1
# loading speaker: MRMG0
# loading speaker: MJEB0
# loading speaker: MJWS0
# loading speaker: MDJM0
# loading speaker: FKSR0
# loading speaker: MEAL0
# loading speaker: MDPS0
# loading speaker: MJMM0
# loading speaker: MRSP0
# loading speaker: FEAR0
# loading speaker: FDTD0
# loading speaker: MDHL0
# loading speaker: FBAS0
# loading speaker: MGRP0
# loading speaker: FSAG0
# loading speaker: MJAE0
# loading speaker: FCMM0
# loading speaker: MEDR0
# loading speaker: MWGR0
# loading speaker: MGXP0
# loading speaker: FSMA0
# loading speaker: MSFH0
# loading speaker: FCLT0
# loading speaker: MSAT1
# loading speaker: FDML0
# loading speaker: MTCS0
# loading speaker: MAEB0
# loading speaker: MJRG0
# loading speaker: FKDW0
# loading speaker: MARC0
# loading speaker: FCMG0
# loading speaker: MDLC2
# loading speaker: MDWH0
# loading speaker: MTRT0
# loading speaker: MGAR0
# loading speaker: MTLC0
# loading speaker: FCDR1
# loading speaker: MAKB0
# loading speaker: MSAT0
# loading speaker: MSMR0
# loading speaker: FPAF0
# loading speaker: MMAG0
# loading speaker: MREE0
# loading speaker: MTPR0
# loading speaker: MTBC0
# loading speaker: MJLS0
# loading speaker: MRVG0
# loading speaker: MJWT0
# loading speaker: MJEE0
# loading speaker: FPLS0
# loading speaker: FLMC0
# loading speaker: MDKS0
# loading speaker: MBML0
# loading speaker: MMAM0
# loading speaker: MLBC0
# loading speaker: MDDC0
# loading speaker: MCLM0
# loading speaker: MMGK0
# loading speaker: MPRT0
# loading speaker: MDAS0
# loading speaker: FSJW0
# loading speaker: MKDD0
# loading speaker: MRLK0
# loading speaker: MPGH0
# loading speaker: MDSS1
# loading speaker: MNET0
# loading speaker: MRDD0
# loading speaker: MFER0
# loading speaker: MHXL0
# loading speaker: MFXS0
# loading speaker: FDJH0
# loading speaker: MRFK0
# loading speaker: MRJM0
# loading speaker: MKLS0
# loading speaker: FEAC0
# loading speaker: FEME0
# loading speaker: MJJM0
# loading speaker: MBGT0
# loading speaker: FSMS1
# loading speaker: MPMB0
# loading speaker: FLJD0
# loading speaker: MDCD0
# loading speaker: FLET0
# loading speaker: MCPM0
# loading speaker: MBAR0
# loading speaker: MPPC0
# loading speaker: MRSO0
# loading speaker: FKLC0
# loading speaker: MRJM1
# loading speaker: MCTM0
# loading speaker: FKDE0
# loading speaker: MJLB0
# loading speaker: MDCM0
# loading speaker: FMJU0
# loading speaker: MMSM0
# loading speaker: MJDM0
# loading speaker: FBCG1
# loading speaker: MSRG0
# loading speaker: FJLR0
# loading speaker: MDSS0
# loading speaker: MREW1
# loading speaker: FVMH0
# loading speaker: FJEN0
# loading speaker: FKLC1
# loading speaker: MKRG0
# loading speaker: FLJG0
# loading speaker: MSMC0
# loading speaker: MJFH0
# loading speaker: MJDG0
# loading speaker: MADC0
# loading speaker: MRDM0
# loading speaker: MKLS1
# loading speaker: FMKF0
# loading speaker: MTKD0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-e41e2d282d43> in <module>
# ----> 1 X, y,X_val, y_val, c, c_val =convertAudio(train_audio_folder)
#       2 print(X.shape)
#       3 print(c)
#
# <ipython-input-8-cd9572a26ec6> in convertAudio(path, n)
#      61         #print(speaker_dict)
#      62     y = np.vstack(y)
# ---> 63     X = np.stack(X)
#      64     y_val = np.vstack(y_val)
#      65     X_val = np.stack(X_val)
#
# <__array_function__ internals> in stack(*args, **kwargs)
#
# ~/opt/anaconda3/envs/iti108/lib/python3.7/site-packages/numpy/core/shape_base.py in stack(arrays, axis, out)
#     424     shapes = {arr.shape for arr in arrays}
#     425     if len(shapes) != 1:
# --> 426         raise ValueError('all input arrays must have the same shape')
#     427
#     428     result_ndim = arrays[0].ndim + 1
#
# ValueError: all input arrays must have the same shape

# %%
print(X.shape)
print(c)
# Out:
# (462, 10, 188, 40)
# {'MDNS0': [0, 9], 'FCRZ0': [10, 19], 'MMDM0': [20, 29], 'MKXL0': [30, 39], 'MESJ0': [40, 49], 'MRAV0': [50, 59], 'FECD0': [60, 69], 'FJKL0': [70, 79], 'MCSS0': [80, 89], 'MWRE0': [90, 99], 'FDNC0': [100, 109], 'MPRD0': [110, 119], 'MCDR0': [120, 129], 'MDAC0': [130, 139], 'FSJG0': [140, 149], 'MRLJ1': [150, 159], 'MKDT0': [160, 169], 'MLEL0': [170, 179], 'MAKR0': [180, 189], 'MAFM0': [190, 199], 'FEEH0': [200, 209], 'MGAK0': [210, 219], 'MPSW0': [220, 229], 'MMDG0': [230, 239], 'MVRW0': [240, 249], 'MWCH0': [250, 259], 'MFWK0': [260, 269], 'MILB0': [270, 279], 'FNTB0': [280, 289], 'FNKL0': [290, 299], 'FKLH0': [300, 309], 'MTJU0': [310, 319], 'MHBS0': [320, 329], 'MRLJ0': [330, 339], 'FPMY0': [340, 349], 'MJHI0': [350, 359], 'MRMS0': [360, 369], 'MJWG0': [370, 379], 'MEFG0': [380, 389], 'FBLV0': [390, 399], 'MRBC0': [400, 409], 'FMMH0': [410, 419], 'FPJF0': [420, 429], 'MRGS0': [430, 439], 'MKAG0': [440, 449], 'FDAS1': [450, 459], 'MMDM1': [460, 469], 'FSBK0': [470, 479], 'MHRM0': [480, 489], 'MKAM0': [490, 499], 'MKLR0': [500, 509], 'FMEM0': [510, 519], 'FKFB0': [520, 529], 'MWEM0': [530, 539], 'MWAD0': [540, 549], 'MAPV0': [550, 559], 'FJXM0': [560, 569], 'MBSB0': [570, 579], 'MJDE0': [580, 589], 'MSEM1': [590, 599], 'MPGR1': [600, 609], 'MRTC0': [610, 619], 'MRKM0': [620, 629], 'FTBR0': [630, 639], 'MTAT0': [640, 649], 'MGES0': [650, 659], 'MSMS0': [660, 669], 'MRJT0': [670, 679], 'MJMA0': [680, 689], 'MRAM0': [690, 699], 'MTJM0': [700, 709], 'MGJC0': [710, 719], 'MRLR0': [720, 729], 'MRRE0': [730, 739], 'FGDP0': [740, 749], 'MTJG0': [750, 759], 'MRPC1': [760, 769], 'MEJS0': [770, 779], 'MJFR0': [780, 789], 'MMCC0': [790, 799], 'MDMT0': [800, 809], 'MAJP0': [810, 819], 'MDLM0': [820, 829], 'FJHK0': [830, 839], 'MCDC0': [840, 849], 'FCJS0': [850, 859], 'MGSH0': [860, 869], 'FLKM0': [870, 879], 'MCHL0': [880, 889], 'MMGC0': [890, 899], 'FLOD0': [900, 909], 'MJXL0': [910, 919], 'MDSJ0': [920, 929], 'MMBS0': [930, 939], 'MTPP0': [940, 949], 'MTAT1': [950, 959], 'MRMH0': [960, 969], 'FVFB0': [970, 979], 'MPGR0': [980, 989], 'FCAJ0': [990, 999], 'FLMK0': [1000, 1009], 'FPAD0': [1010, 1019], 'FMJF0': [1020, 1029], 'FLMA0': [1030, 1039], 'MTQC0': [1040, 1049], 'MKJO0': [1050, 1059], 'MREM0': [1060, 1069], 'MRMB0': [1070, 1079], 'FSLS0': [1080, 1089], 'MBWP0': [1090, 1099], 'FLAG0': [1100, 1109], 'MBCG0': [1110, 1119], 'MRTJ0': [1120, 1129], 'MTLB0': [1130, 1139], 'MHMR0': [1140, 1149], 'FSKL0': [1150, 1159], 'MFRM0': [1160, 1169], 'MFMC0': [1170, 1179], 'MDLC1': [1180, 1189], 'MJRH0': [1190, 1199], 'FCEG0': [1200, 1209], 'MMAA0': [1210, 1219], 'MTWH1': [1220, 1229], 'FMBG0': [1230, 1239], 'MRML0': [1240, 1249], 'MSJK0': [1250, 1259], 'MMAB1': [1260, 1269], 'FKKH0': [1270, 1279], 'MLSH0': [1280, 1289], 'MTAS0': [1290, 1299], 'FALK0': [1300, 1309], 'MSVS0': [1310, 1319], 'MSDB0': [1320, 1329], 'MBTH0': [1330, 1339], 'MGSL0': [1340, 1349], 'MCEW0': [1350, 1359], 'MJPG0': [1360, 1369], 'MRXB0': [1370, 1379], 'MMGG0': [1380, 1389], 'MCLK0': [1390, 1399], 'MJPM0': [1400, 1409], 'MGAW0': [1410, 1419], 'MSDH0': [1420, 1429], 'MWDK0': [1430, 1439], 'FLTM0': [1440, 1449], 'MKDB0': [1450, 1459], 'FJSK0': [1460, 1469], 'MCDD0': [1470, 1479], 'MDWM0': [1480, 1489], 'FSAH0': [1490, 1499], 'FLAC0': [1500, 1509], 'FMJB0': [1510, 1519], 'MMWS0': [1520, 1529], 'MMEB0': [1530, 1539], 'FBJL0': [1540, 1549], 'MLJC0': [1550, 1559], 'MJSR0': [1560, 1569], 'MJAC0': [1570, 1579], 'MTKP0': [1580, 1589], 'MRAI0': [1590, 1599], 'MJRK0': [1600, 1609], 'FPAC0': [1610, 1619], 'MDWD0': [1620, 1629], 'MWAR0': [1630, 1639], 'MJRH1': [1640, 1649], 'FSCN0': [1650, 1659], 'MDLC0': [1660, 1669], 'MMWS1': [1670, 1679], 'MBJV0': [1680, 1689], 'MTRR0': [1690, 1699], 'MJXA0': [1700, 1709], 'FRLL0': [1710, 1719], 'MWRP0': [1720, 1729], 'MKLN0': [1730, 1739], 'MJRA0': [1740, 1749], 'MMEA0': [1750, 1759], 'FTAJ0': [1760, 1769], 'FCAG0': [1770, 1779], 'FKAA0': [1780, 1789], 'FJWB1': [1790, 1799], 'FSMM0': [1800, 1809], 'FSAK0': [1810, 1819], 'MJPM1': [1820, 1829], 'MJAI0': [18 ...

# %% [markdown]
# ### Saving the train tensors to disk

# %%
with open(os.path.join(save_path,"train.pickle"), "wb") as f:
    pickle.dump((X,c),f)

# %%
with open(os.path.join(save_path,"validation.pickle"), "wb") as f:
    pickle.dump((X_val,c_val),f)

# %% [markdown]
# ### Loading the validation audio  into tensors

# %%
X_test, y_test,c_test=convertAudio(test_audio_folder)
print(X_test.shape)
print(c_test)
# Out:
# loading speaker: MERS0
# loading speaker: FSLB1
# loading speaker: MRMS1
# loading speaker: MJFC0
# loading speaker: MRJO0
# loading speaker: FNLP0
# loading speaker: MGMM0
# loading speaker: MRCS0
# loading speaker: MJVW0
# loading speaker: MJMP0
# loading speaker: MKCH0
# loading speaker: MRCZ0
# loading speaker: MTLS0
# loading speaker: MDRB0
# loading speaker: MCRC0
# loading speaker: MTMR0
# loading speaker: MCSH0
# loading speaker: MWVW0
# loading speaker: FNMR0
# loading speaker: FGWR0
# loading speaker: FAKS0
# loading speaker: MCTW0
# loading speaker: MKJL0
# loading speaker: FRNG0
# loading speaker: MPLB0
# loading speaker: MJTC0
# loading speaker: FLKD0
# loading speaker: MDSC0
# loading speaker: FREW0
# loading speaker: MJBR0
# loading speaker: MDLD0
# loading speaker: MCTT0
# loading speaker: MJRF0
# loading speaker: FCRH0
# loading speaker: MRPC0
# loading speaker: FCMH0
# loading speaker: FJSA0
# loading speaker: FDRD1
# loading speaker: MRJS0
# loading speaker: MCHH0
# loading speaker: MGLB0
# loading speaker: FAWF0
# loading speaker: FMLD0
# loading speaker: MMJR0
# loading speaker: FJWB0
# loading speaker: MLLL0
# loading speaker: MTAS1
# loading speaker: MMAB0
# loading speaker: FCMH1
# loading speaker: MTWH0
# loading speaker: FJAS0
# loading speaker: FADG0
# loading speaker: MRRK0
# loading speaker: MSJS1
# loading speaker: FMML0
# loading speaker: FCAU0
# loading speaker: MKCL0
# loading speaker: MMWH0
# loading speaker: MBDG0
# loading speaker: MJLN0
# loading speaker: MRJM3
# loading speaker: FLNH0
# loading speaker: FJMG0
# loading speaker: MRJM4
# loading speaker: MGWT0
# loading speaker: MTEB0
# loading speaker: MJDH0
# loading speaker: MJAR0
# loading speaker: MESD0
# loading speaker: FASW0
# loading speaker: MPAB0
# loading speaker: MTAA0
# loading speaker: MCMJ0
# loading speaker: FMAH0
# loading speaker: MMDH0
# loading speaker: MBWM0
# loading speaker: FMCM0
# loading speaker: MWBT0
# loading speaker: FMGD0
# loading speaker: FPAS0
# loading speaker: MKLT0
# loading speaker: MDLS0
# loading speaker: MCEM0
# loading speaker: MDRM0
# loading speaker: MCMB0
# loading speaker: MKDR0
# loading speaker: MJES0
# loading speaker: FCMR0
# loading speaker: FLAS0
# loading speaker: FDHC0
# loading speaker: MAHH0
# loading speaker: MHPG0
# loading speaker: MPGL0
# loading speaker: FDMS0
# loading speaker: MRES0
# loading speaker: FDRW0
# loading speaker: MDAC2
# loading speaker: FHES0
# loading speaker: MMDM2
# loading speaker: FEDW0
# loading speaker: FGJD0
# loading speaker: MMDB1
# loading speaker: MLJB0
# loading speaker: MGJF0
# loading speaker: MCCS0
# loading speaker: MROA0
# loading speaker: FJLM0
# loading speaker: MRWS1
# loading speaker: MFGK0
# loading speaker: FLBW0
# loading speaker: MREB0
# loading speaker: FCAL1
# loading speaker: MGRT0
# loading speaker: MRJR0
# loading speaker: FISB0
# loading speaker: FELC0
# loading speaker: MRGG0
# loading speaker: FJSJ0
# loading speaker: FSXA0
# loading speaker: MDAW1
# loading speaker: MDBB0
# loading speaker: MPWM0
# loading speaker: FCFT0
# loading speaker: MBNS0
# loading speaker: MRKO0
# loading speaker: MABW0
# loading speaker: FGMD0
# loading speaker: MNLS0
# loading speaker: MWJG0
# loading speaker: MRTK0
# loading speaker: MWEW0
# loading speaker: MSLB0
# loading speaker: FDAC1
# loading speaker: MDLF0
# loading speaker: MSFH1
# loading speaker: MPDF0
# loading speaker: MDWA0
# loading speaker: MTHC0
# loading speaker: MJTH0
# loading speaker: FSEM0
# loading speaker: MJSW0
# loading speaker: FJCS0
# loading speaker: MPCS0
# loading speaker: MBPM0
# loading speaker: MDWK0
# loading speaker: MPAM1
# loading speaker: MJDM1
# loading speaker: MJJG0
# loading speaker: MAJC0
# loading speaker: MLIH0
# loading speaker: FPKT0
# loading speaker: FJEM0
# loading speaker: MBJK0
# loading speaker: FHEW0
# loading speaker: FRAM1
# loading speaker: FTLH0
# loading speaker: FKMS0
# loading speaker: MLNT0
# loading speaker: FJRE0
# loading speaker: MPAM0
# loading speaker: MDVC0
# loading speaker: MRPP0
# loading speaker: MDAB0
# loading speaker: MTDT0
# loading speaker: MNJM0
# loading speaker: FMAF0
# loading speaker: MSTK0
# loading speaker: FUTB0
# (168, 10, 188, 40)
# {'MERS0': [0, 9], 'FSLB1': [10, 19], 'MRMS1': [20, 29], 'MJFC0': [30, 39], 'MRJO0': [40, 49], 'FNLP0': [50, 59], 'MGMM0': [60, 69], 'MRCS0': [70, 79], 'MJVW0': [80, 89], 'MJMP0': [90, 99], 'MKCH0': [100, 109], 'MRCZ0': [110, 119], 'MTLS0': [120, 129], 'MDRB0': [130, 139], 'MCRC0': [140, 149], 'MTMR0': [150, 159], 'MCSH0': [160, 169], 'MWVW0': [170, 179], 'FNMR0': [180, 189], 'FGWR0': [190, 199], 'FAKS0': [200, 209], 'MCTW0': [210, 219], 'MKJL0': [220, 229], 'FRNG0': [230, 239], 'MPLB0': [240, 249], 'MJTC0': [250, 259], 'FLKD0': [260, 269], 'MDSC0': [270, 279], 'FREW0': [280, 289], 'MJBR0': [290, 299], 'MDLD0': [300, 309], 'MCTT0': [310, 319], 'MJRF0': [320, 329], 'FCRH0': [330, 339], 'MRPC0': [340, 349], 'FCMH0': [350, 359], 'FJSA0': [360, 369], 'FDRD1': [370, 379], 'MRJS0': [380, 389], 'MCHH0': [390, 399], 'MGLB0': [400, 409], 'FAWF0': [410, 419], 'FMLD0': [420, 429], 'MMJR0': [430, 439], 'FJWB0': [440, 449], 'MLLL0': [450, 459], 'MTAS1': [460, 469], 'MMAB0': [470, 479], 'FCMH1': [480, 489], 'MTWH0': [490, 499], 'FJAS0': [500, 509], 'FADG0': [510, 519], 'MRRK0': [520, 529], 'MSJS1': [530, 539], 'FMML0': [540, 549], 'FCAU0': [550, 559], 'MKCL0': [560, 569], 'MMWH0': [570, 579], 'MBDG0': [580, 589], 'MJLN0': [590, 599], 'MRJM3': [600, 609], 'FLNH0': [610, 619], 'FJMG0': [620, 629], 'MRJM4': [630, 639], 'MGWT0': [640, 649], 'MTEB0': [650, 659], 'MJDH0': [660, 669], 'MJAR0': [670, 679], 'MESD0': [680, 689], 'FASW0': [690, 699], 'MPAB0': [700, 709], 'MTAA0': [710, 719], 'MCMJ0': [720, 729], 'FMAH0': [730, 739], 'MMDH0': [740, 749], 'MBWM0': [750, 759], 'FMCM0': [760, 769], 'MWBT0': [770, 779], 'FMGD0': [780, 789], 'FPAS0': [790, 799], 'MKLT0': [800, 809], 'MDLS0': [810, 819], 'MCEM0': [820, 829], 'MDRM0': [830, 839], 'MCMB0': [840, 849], 'MKDR0': [850, 859], 'MJES0': [860, 869], 'FCMR0': [870, 879], 'FLAS0': [880, 889], 'FDHC0': [890, 899], 'MAHH0': [900, 909], 'MHPG0': [910, 919], 'MPGL0': [920, 929], 'FDMS0': [930, 939], 'MRES0': [940, 949], 'FDRW0': [950, 959], 'MDAC2': [960, 969], 'FHES0': [970, 979], 'MMDM2': [980, 989], 'FEDW0': [990, 999], 'FGJD0': [1000, 1009], 'MMDB1': [1010, 1019], 'MLJB0': [1020, 1029], 'MGJF0': [1030, 1039], 'MCCS0': [1040, 1049], 'MROA0': [1050, 1059], 'FJLM0': [1060, 1069], 'MRWS1': [1070, 1079], 'MFGK0': [1080, 1089], 'FLBW0': [1090, 1099], 'MREB0': [1100, 1109], 'FCAL1': [1110, 1119], 'MGRT0': [1120, 1129], 'MRJR0': [1130, 1139], 'FISB0': [1140, 1149], 'FELC0': [1150, 1159], 'MRGG0': [1160, 1169], 'FJSJ0': [1170, 1179], 'FSXA0': [1180, 1189], 'MDAW1': [1190, 1199], 'MDBB0': [1200, 1209], 'MPWM0': [1210, 1219], 'FCFT0': [1220, 1229], 'MBNS0': [1230, 1239], 'MRKO0': [1240, 1249], 'MABW0': [1250, 1259], 'FGMD0': [1260, 1269], 'MNLS0': [1270, 1279], 'MWJG0': [1280, 1289], 'MRTK0': [1290, 1299], 'MWEW0': [1300, 1309], 'MSLB0': [1310, 1319], 'FDAC1': [1320, 1329], 'MDLF0': [1330, 1339], 'MSFH1': [1340, 1349], 'MPDF0': [1350, 1359], 'MDWA0': [1360, 1369], 'MTHC0': [1370, 1379], 'MJTH0': [1380, 1389], 'FSEM0': [1390, 1399], 'MJSW0': [1400, 1409], 'FJCS0': [1410, 1419], 'MPCS0': [1420, 1429], 'MBPM0': [1430, 1439], 'MDWK0': [1440, 1449], 'MPAM1': [1450, 1459], 'MJDM1': [1460, 1469], 'MJJG0': [1470, 1479], 'MAJC0': [1480, 1489], 'MLIH0': [1490, 1499], 'FPKT0': [1500, 1509], 'FJEM0': [1510, 1519], 'MBJK0': [1520, 1529], 'FHEW0': [1530, 1539], 'FRAM1': [1540, 1549], 'FTLH0': [1550, 1559], 'FKMS0': [1560, 1569], 'MLNT0': [1570, 1579], 'FJRE0': [1580, 1589], 'MPAM0': [1590, 1599], 'MDVC0': [1600, 1609], 'MRPP0': [1610, 1619], 'MDAB0': [1620, 1629], 'MTDT0': [1630, 1639], 'MNJM0': [1640, 1649], 'FMAF0': [1650, 1659], 'MSTK0': [1660, 1669], 'FUTB0': [1670, 1679]}

# %%
#Xval,yval,cval=loadimgs(val_folder)

# %% [markdown]
# ### Saving the validation tensors on disk

# %%
with open(os.path.join(save_path,"val.pickle"), "wb") as f:
    pickle.dump((X_test, c_test),f)
